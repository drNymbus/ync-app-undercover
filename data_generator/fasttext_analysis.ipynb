# %%
# !pip install fasttext
# !pip install levenshtein

import fasttext
import fasttext.util
from Levenshtein import distance

import urllib.request
import json
# Out:
# Requirement already satisfied: fasttext in /usr/local/lib/python3.11/dist-packages (0.9.3)
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.11/dist-packages (from fasttext) (2.13.6)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from fasttext) (75.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from fasttext) (2.0.2)
# Requirement already satisfied: levenshtein in /usr/local/lib/python3.11/dist-packages (0.27.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in /usr/local/lib/python3.11/dist-packages (from levenshtein) (3.13.0)

# %%
# Load model
# fasttext.util.download_model('fr', if_exists='ignore')
ft = fasttext.load_model('cc.fr.300.bin')

# Load words
words = []
with open('/content/freq_word_clean.txt', 'r') as file:
    words = file.read().splitlines()

# %%
# Look how the model behave on just a few words
for word in words[:5]:
    neighbors = ft.get_nearest_neighbors(word)
    for d, n in neighbors:
        n = n.split('.')[0]
    print(word, [n for _, n in neighbors])
# Out:
# bleu ['violet', 'jaune', 'rouge', 'bleu.Le', 'gris', 'vert', 'blanc', 'noir', 'turquoise', 'mauve']
# super ['sympa', 'suuuuuper', 'suuuuuuper', 'très', 'suuuuper', 'hyper', 'génial', 'suuuper', 'chouette', 'supers']
# autre ['part', 'quelque', 'chose', 'une', 'autre.Une', 'quelconque', 'seule', "autre.D'", 'côté', 'même']
# bizarre ['bizzare', 'étrange', 'bizare', 'bizard', 'marrant', 'bizarrement', 'bizzarre', 'chelou', 'bizzard', 'bizarre.']
# difficile ['compliqué', 'difficle', 'facile', 'compliquée', 'impossible', 'ardu', 'difficiles', 'évident', 'ardue', 'diffcile']

# %% [markdown]
# Grâce au modèle de fasttext, on obtient une liste des 10 mots les plus rapprochés ainsi que leur distance associées. Dans notre cas, ces distances ne sont pas vraiment représentative d'une bonne association permettant une partie excitante d'Undercover. Il va falloir trouver un moyen de filtrer et réordonner ces mots dans un ordre qui nous convient mieux.
#
# On peut également remarquer que parmis les mots voisins se trouvent le même mot ortographié de manières différentes (majuscules, ponctuation, pluriel). Commençons par écarter ses voisins ci. Pour filtrer, nous allons d'abord nous débarasser de la ponctuation (appelé stopwords) et comparer la distance de Levenshtein entre le mot d'origine et un voisin.
#
# Pour illustrer le propos nous allons nous concentrer sur le mot: 'impossible'

# %%
example = 'impossible'
ft_neighbors = ft.get_nearest_neighbors(example)
example, ft_neighbors
# Out:
# ('impossible',
#  [(0.7440884113311768, 'difficile'),
#   (0.7319589257240295, 'quasi-impossible'),
#   (0.7296919822692871, 'impossibles'),
#   (0.7182818651199341, 'impensable'),
#   (0.6970745921134949, 'inconcevable'),
#   (0.6799744367599487, 'impossible.'),
#   (0.6762660145759583, 'impossible.Il'),
#   (0.6699529886245728, 'possible'),
#   (0.6698157787322998, 'inenvisageable'),
#   (0.6677538156509399, 'envisageable')])

# %%
stopwords = '?,.;/:-_<>'

neighbors = {}
for d, n in ft_neighbors:
    # new_n = n
    for sw in stopwords:
        n = n.split(sw)[0]
    if distance(example, n) > 1 and n != '':
        neighbors[n] = {'distance':d}

neighbors
# Out:
# {'difficile': {'distance': 0.7440884113311768},
#  'quasi': {'distance': 0.7319589257240295},
#  'impensable': {'distance': 0.7182818651199341},
#  'inconcevable': {'distance': 0.6970745921134949},
#  'possible': {'distance': 0.6699529886245728},
#  'inenvisageable': {'distance': 0.6698157787322998},
#  'envisageable': {'distance': 0.6677538156509399}}

# %% [markdown]
# Maintenant que nous avons écarté les mots similaires. Il nous faut faire un choix entre ceux restant. Pour s'assurer de la cohérence de l'association des mots, nous partons sur le concept d'[hyponymie](https://fr.wikipedia.org/wiki/Hyponymie).
#
# Nous allons garder, parmis les voisins restants, ceux qui possèdent un hypéronyme commun. Pour ce faire nous allons consulter la base de données [JeuxDeMots](https://www.jeuxdemots.org/jdm-about.php) pour regarder les relations d'hyponyme entre le mot d'origine et un voisin, si tout deux ont un mot similaire dans ces relations nous conserverons

# %%
URI = 'https://jdm-api.demo.lirmm.fr/v0'

def get_relations_type(word, relation):
    relations = []
    try:
        url = f'{URI}/relations/from/{urllib.parse.quote(word)}?types_ids={relation}'
        response = urllib.request.urlopen(url)
        content = json.load(response)
        for node in content['nodes']:
            relations.append(node['name'])
    except Exception as e:
        print(f'Bad request node={word}({relation}): "{e}"')
    return relations

def get_relations(word):
    relations = []
    relations.extend(get_relations_type(word, 7))
    relations.extend(get_relations_type(word, 8))
    relations.extend(get_relations_type(word, 10))
    relations.extend(get_relations_type(word, 35))
    relations.extend(get_relations_type(word, 36))
    return relations

# %%
hypo_word = get_relations(example)

for n in neighbors:
    hypo_n = get_relations(n)
    neighbors[n]['hypo'] = len(list(set(hypo_word) & set(hypo_n)))

neighbors
# Out:
# {'difficile': {'distance': 0.7440884113311768, 'hypo': 18},
#  'quasi': {'distance': 0.7319589257240295, 'hypo': 11},
#  'impensable': {'distance': 0.7182818651199341, 'hypo': 15},
#  'inconcevable': {'distance': 0.6970745921134949, 'hypo': 19},
#  'possible': {'distance': 0.6699529886245728, 'hypo': 16},
#  'inenvisageable': {'distance': 0.6698157787322998, 'hypo': 18},
#  'envisageable': {'distance': 0.6677538156509399, 'hypo': 16}}

# %% [markdown]
# On classe les voisins par la distance et le nombre de relation en communs, on sélectionne les 3 premiers pour former 3 associations de mots.

# %%
sorted_neighbors = dict(sorted(neighbors.items(), key=lambda item: item[1]['hypo'])[-3:])
with open('/content/undercover.txt', 'w+') as file:
    for neighbor in sorted_neighbors:
        file.write(f'{example}:{neighbor}\n')

# %% [markdown]
# On automatise le tout

# %%
def get_neighbors(word):
    stopwords = '?,.;/:-_<>'

    neighbors = {}
    for d, n in ft.get_nearest_neighbors(word):
        # new_n = n
        for sw in stopwords:
            n = n.split(sw)[0]
        if distance(word, n) > 1 and n != '':
            neighbors[n] = {'distance':d}
            hypo_n = get_relations(n)
            neighbors[n]['hypo'] = len(list(set(hypo_word) & set(hypo_n)))
    return neighbors

def get_undercover_relations(word):
    relations = []
    neighbors = get_neighbors(word)
    neighbors = dict(sorted(neighbors.items(), key=lambda item: item[1]['hypo'])[-3:])
    for n in neighbors:
        relations.append((word, n))
    return relations

# %%
undercover_file = open('/content/undercover.txt', 'w')
with open('/content/freq_word_clean.txt', 'r') as file:
    for word in file.read().splitlines():
        print(word)
        for w1, w2 in get_undercover_relations(word):
            print('\t', w1, w2)
            undercover_file.write(f'{w1}:{w2}\n')
# Out:
# bleu
# 	 bleu noir
# 	 bleu turquoise
# 	 bleu rouge
# super
# Bad request node=suuuuuper(7): "HTTP Error 500: Internal Server Error"
# Bad request node=suuuuuper(8): "HTTP Error 500: Internal Server Error"
# Bad request node=suuuuuper(10): "HTTP Error 500: Internal Server Error"
# Bad request node=suuuuuper(35): "HTTP Error 500: Internal Server Error"
# Bad request node=suuuuuper(36): "HTTP Error 500: Internal Server Error"
# Bad request node=suuuuuuper(7): "HTTP Error 500: Internal Server Error"
# Bad request node=suuuuuuper(8): "HTTP Error 500: Internal Server Error"
# Bad request node=suuuuuuper(10): "HTTP Error 500: Internal Server Error"
# Bad request node=suuuuuuper(35): "HTTP Error 500: Internal Server Error"
# Bad request node=suuuuuuper(36): "HTTP Error 500: Internal Server Error"
# Bad request node=suuuuper(7): "HTTP Error 500: Internal Server Error"
# Bad request node=suuuuper(8): "HTTP Error 500: Internal Server Error"
# Bad request node=suuuuper(10): "HTTP Error 500: Internal Server Error"
# Bad request node=suuuuper(35): "HTTP Error 500: Internal Server Error"
# Bad request node=suuuuper(36): "HTTP Error 500: Internal Server Error"
# Bad request node=suuuper(7): "HTTP Error 500: Internal Server Error"
# Bad request node=suuuper(8): "HTTP Error 500: Internal Server Error"
# Bad request node=suuuper(10): "HTTP Error 500: Internal Server Error"
# Bad request node=suuuper(35): "HTTP Error 500: Internal Server Error"
# Bad request node=suuuper(36): "HTTP Error 500: Internal Server Error"
# 	 super très
# 	 super génial
# 	 super hyper
# autre
# 	 autre quelque
# 	 autre seule
# 	 autre quelconque
# bizarre
# Bad request node=bizzare(7): "HTTP Error 500: Internal Server Error"
# Bad request node=bizzare(8): "HTTP Error 500: Internal Server Error"
# Bad request node=bizzare(10): "HTTP Error 500: Internal Server Error"
# Bad request node=bizzare(35): "HTTP Error 500: Internal Server Error"
# Bad request node=bizzare(36): "HTTP Error 500: Internal Server Error"
# Bad request node=bizard(7): "HTTP Error 500: Internal Server Error"
# Bad request node=bizard(8): "HTTP Error 500: Internal Server Error"
# Bad request node=bizard(10): "HTTP Error 500: Internal Server Error"
# Bad request node=bizard(35): "HTTP Error 500: Internal Server Error"
# Bad request node=bizard(36): "HTTP Error 500: Internal Server Error"
# Bad request node=bizzard(7): "HTTP Error 500: Internal Server Error"
# Bad request node=bizzard(8): "HTTP Error 500: Internal Server Error"
# Bad request node=bizzard(10): "HTTP Error 500: Internal Server Error"
# Bad request node=bizzard(35): "HTTP Error 500: Internal Server Error"
# Bad request node=bizzard(36): "HTTP Error 500: Internal Server Error"
# 	 bizarre bizarrement
# 	 bizarre étrange
# 	 bizarre marrant
# difficile
# 	 difficile compliqué
# 	 difficile ardu
# 	 difficile impossible
# drôle
# 	 drôle cocasse
# 	 drôle rigolo
# 	 drôle marrant
# étrange
# 	 étrange inquiétant
# 	 étrange intrigant
# 	 étrange bizarre
# facile
# 	 facile aisé
# 	 facile compliqué
# 	 facile difficile
# grave
# 	 grave gravissime
# 	 grave terrible
# impossible
# 	 impossible difficile
# 	 impossible inenvisageable
# 	 impossible inconcevable
# jeune
# Bad request node=unjeune(7): "HTTP Error 500: Internal Server Error"
# Bad request node=unjeune(8): "HTTP Error 500: Internal Server Error"
# Bad request node=unjeune(10): "HTTP Error 500: Internal Server Error"
# Bad request node=unjeune(35): "HTTP Error 500: Internal Server Error"
# Bad request node=unjeune(36): "HTTP Error 500: Internal Server Error"
# 	 jeune quadragénaire
# 	 jeune adolescent
# 	 jeune femme
# juste
# Bad request node=jsute(7): "HTTP Error 500: Internal Server Error"
# Bad request node=jsute(8): "HTTP Error 500: Internal Server Error"
# Bad request node=jsute(10): "HTTP Error 500: Internal Server Error"
# Bad request node=jsute(35): "HTTP Error 500: Internal Server Error"
# Bad request node=jsute(36): "HTTP Error 500: Internal Server Error"
# 	 juste bien
# 	 juste simplement
# 	 juste surtout
# libre
# 	 libre liberté
# malade
# 	 malade guéri
# 	 malade bien
# 	 malade alité
# même
# 	 même pourtant
# 	 même alors
# 	 même surtout
# pauvre
# 	 pauvre riche
# 	 pauvre hère
# 	 pauvre misérable
# possible
# 	 possible faisable
# 	 possible réalisable
# 	 possible impossible
# propre
# Bad request node=sapropre(7): "HTTP Error 500: Internal Server Error"
# Bad request node=sapropre(8): "HTTP Error 500: Internal Server Error"
# Bad request node=sapropre(10): "HTTP Error 500: Internal Server Error"
# Bad request node=sapropre(35): "HTTP Error 500: Internal Server Error"
# Bad request node=sapropre(36): "HTTP Error 500: Internal Server Error"
# 	 propre son
# 	 propre fonctionnel
# 	 propre leur
# rouge
# Bad request node=rougeet(7): "HTTP Error 500: Internal Server Error"
# Bad request node=rougeet(8): "HTTP Error 500: Internal Server Error"
# Bad request node=rougeet(10): "HTTP Error 500: Internal Server Error"
# Bad request node=rougeet(35): "HTTP Error 500: Internal Server Error"
# Bad request node=rougeet(36): "HTTP Error 500: Internal Server Error"
# 	 rouge jaune
# 	 rouge vert
# 	 rouge noir
# sale
# Bad request node=dégoutante(7): "HTTP Error 500: Internal Server Error"
# Bad request node=dégoutante(8): "HTTP Error 500: Internal Server Error"
# Bad request node=dégoutante(10): "HTTP Error 500: Internal Server Error"
# Bad request node=dégoutante(35): "HTTP Error 500: Internal Server Error"
# Bad request node=dégoutante(36): "HTTP Error 500: Internal Server Error"
# 	 sale dégueulasse
# 	 sale saleté
# 	 sale crade
# simple
# 	 simple simpliste
# 	 simple compliqué
# 	 simple ultra
# tranquille
# Bad request node=tranquil(7): "HTTP Error 500: Internal Server Error"
# Bad request node=tranquil(8): "HTTP Error 500: Internal Server Error"
# Bad request node=tranquil(10): "HTTP Error 500: Internal Server Error"
# Bad request node=tranquil(35): "HTTP Error 500: Internal Server Error"
# Bad request node=tranquil(36): "HTTP Error 500: Internal Server Error"
# 	 tranquille paisible
# 	 tranquille calme
# 	 tranquille serein
# triste
# 	 triste tragique
# 	 triste déprimant
# 	 triste pathétique
# vide
# 	 vide quasi
# 	 vide grenier
# bonne
# Bad request node=exellente(7): "HTTP Error 500: Internal Server Error"
# Bad request node=exellente(8): "HTTP Error 500: Internal Server Error"
# Bad request node=exellente(10): "HTTP Error 500: Internal Server Error"
# Bad request node=exellente(35): "HTTP Error 500: Internal Server Error"
# Bad request node=exellente(36): "HTTP Error 500: Internal Server Error"
# 	 bonne belle
# 	 bonne nouvelle
# 	 bonne une
# toute
# 	 toute entière
# 	 toute façon
# 	 toute seule
# doux
# 	 doux voluptueux
# 	 doux ultra
# 	 doux soyeux
# faux
# 	 faux archi
# 	 faux vrais
# 	 faux vrai
# français
# 	 français espagnol
# 	 français allemand
# 	 français portugais
# gros
# Bad request node=groooos(7): "HTTP Error 500: Internal Server Error"
# Bad request node=groooos(8): "HTTP Error 500: Internal Server Error"
# Bad request node=groooos(10): "HTTP Error 500: Internal Server Error"
# Bad request node=groooos(35): "HTTP Error 500: Internal Server Error"
# Bad request node=groooos(36): "HTTP Error 500: Internal Server Error"
# Bad request node=grooooos(7): "HTTP Error 500: Internal Server Error"
# Bad request node=grooooos(8): "HTTP Error 500: Internal Server Error"
# Bad request node=grooooos(10): "HTTP Error 500: Internal Server Error"
# Bad request node=grooooos(35): "HTTP Error 500: Internal Server Error"
# Bad request node=grooooos(36): "HTTP Error 500: Internal Server Error"
# Bad request node=grooos(7): "HTTP Error 500: Internal Server Error"
# Bad request node=grooos(8): "HTTP Error 500: Internal Server Error"
# Bad request node=grooos(10): "HTTP Error 500: Internal Server Error"
# Bad request node=grooos(35): "HTTP Error 500: Internal Server Error"
# Bad request node=grooos(36): "HTTP Error 500: Internal Server Error"
# Bad request node=groooooos(7): "HTTP Error 500: Internal Server Error"
# Bad request node=groooooos(8): "HTTP Error 500: Internal Server Error"
# Bad request node=groooooos(10): "HTTP Error 500: Internal Server Error"
# Bad request node=groooooos(35): "HTTP Error 500: Internal Server Error"
# Bad request node=groooooos(36): "HTTP Error 500: Internal Server Error"
# 	 gros petit
# 	 gros grand
# 	 gros énorme
# heureux
# 	 heureux fiers
# 	 heureux ravi
# 	 heureux chanceux
# mauvais
# 	 mauvais bon
# 	 mauvais bons
# sérieux
# 	 sérieux sérieuse
# vieux
# 	 vieux chnoque
# 	 vieux schnock
# 	 vieux vieil
# vrai
# 	 vrai évident
# 	 vrai véritable
# 	 vrai surtout
# ancien
# 	 ancien ancienne
# 	 ancien vieil
# 	 ancien actuel
# beau
# 	 beau magnifique
# 	 beau superbe
# 	 beau joli
# blanc
# 	 blanc noir
# 	 blanc jaune
# 	 blanc rouge
# certain
# 	 certain certainement
# 	 certain évident
# 	 certain seul
# chaud
# 	 chaud sec
# 	 chaud froid
# cher
# 	 cher chère
# clair
# 	 clair évident
# 	 clair limpide
# content
# 	 content satisfait
# 	 content fier
# 	 content heureux
# dernier
# 	 dernier deuxième
# 	 dernier prochain
# 	 dernier troisième
# désolé
# 	 désolé excusez
# 	 désolé navré
# 	 désolé désoler
# différent
# 	 différent identique
# 	 différent distinct
# 	 différent semblable
# droit
# Bad request node=droitde(7): "HTTP Error 500: Internal Server Error"
# Bad request node=droitde(8): "HTTP Error 500: Internal Server Error"
# Bad request node=droitde(10): "HTTP Error 500: Internal Server Error"
# Bad request node=droitde(35): "HTTP Error 500: Internal Server Error"
# Bad request node=droitde(36): "HTTP Error 500: Internal Server Error"
# Bad request node=droitd'(7): "HTTP Error 500: Internal Server Error"
# Bad request node=droitd'(8): "HTTP Error 500: Internal Server Error"
# Bad request node=droitd'(10): "HTTP Error 500: Internal Server Error"
# Bad request node=droitd'(35): "HTTP Error 500: Internal Server Error"
# Bad request node=droitd'(36): "HTTP Error 500: Internal Server Error"
# 	 droit droitde
# 	 droit droitd'
# entier
# Bad request node=particulieret(7): "HTTP Error 500: Internal Server Error"
# Bad request node=particulieret(8): "HTTP Error 500: Internal Server Error"
# Bad request node=particulieret(10): "HTTP Error 500: Internal Server Error"
# Bad request node=particulieret(35): "HTTP Error 500: Internal Server Error"
# Bad request node=particulieret(36): "HTTP Error 500: Internal Server Error"
# 	 entier particulieret
# 	 entier monde
# 	 entier tout
# fort
# 	 fort faible
# 	 fort extraordinairement
# 	 fort particulièrement
# froid
# Bad request node=froidLe(7): "HTTP Error 500: Internal Server Error"
# Bad request node=froidLe(8): "HTTP Error 500: Internal Server Error"
# Bad request node=froidLe(10): "HTTP Error 500: Internal Server Error"
# Bad request node=froidLe(35): "HTTP Error 500: Internal Server Error"
# Bad request node=froidLe(36): "HTTP Error 500: Internal Server Error"
# 	 froid froidLe
# 	 froid chaud
# 	 froid glacial
# gentil
# 	 gentil méchant
# 	 gentil serviable
# 	 gentil sympathique
# grand
# 	 grand seul
# 	 grand énorme
# 	 grand certain
# haut
# Bad request node=hautde(7): "HTTP Error 500: Internal Server Error"
# Bad request node=hautde(8): "HTTP Error 500: Internal Server Error"
# Bad request node=hautde(10): "HTTP Error 500: Internal Server Error"
# Bad request node=hautde(35): "HTTP Error 500: Internal Server Error"
# Bad request node=hautde(36): "HTTP Error 500: Internal Server Error"
# 	 haut niveau
# 	 haut dessus
# 	 haut bas
# humain
# 	 humain pré
# 	 humain non
# 	 humain animal
# important
# 	 important évident
# 	 important considérable
# 	 important essentiel
# joli
# 	 joli ravissant
# 	 joli superbe
# 	 joli magnifique
# léger
# 	 léger légère
# 	 léger lourd
# 	 léger élégant
# long
# Bad request node=loooong(7): "HTTP Error 500: Internal Server Error"
# Bad request node=loooong(8): "HTTP Error 500: Internal Server Error"
# Bad request node=loooong(10): "HTTP Error 500: Internal Server Error"
# Bad request node=loooong(35): "HTTP Error 500: Internal Server Error"
# Bad request node=loooong(36): "HTTP Error 500: Internal Server Error"
# 	 long bout
# 	 long début
# 	 long laps
# meilleur
# 	 meilleur bon
# 	 meilleur pire
# 	 meilleur excellent
# mort
# 	 mort disparition
# 	 mort résurrection
# 	 mort mourant
# noir
# 	 noir bleu
# 	 noir blanc
# 	 noir rouge
# nouveau
# 	 nouveau son
# 	 nouveau petit
# 	 nouveau futur
# pareil
# 	 pareil truc
# 	 pareil bizarre
# 	 pareil marrant
# petit
# Bad request node=unpetit(7): "HTTP Error 500: Internal Server Error"
# Bad request node=unpetit(8): "HTTP Error 500: Internal Server Error"
# Bad request node=unpetit(10): "HTTP Error 500: Internal Server Error"
# Bad request node=unpetit(35): "HTTP Error 500: Internal Server Error"
# Bad request node=unpetit(36): "HTTP Error 500: Internal Server Error"
# 	 petit grand
# 	 petit seul
# 	 petit joli
# plein
# Bad request node=pleinde(7): "HTTP Error 500: Internal Server Error"
# Bad request node=pleinde(8): "HTTP Error 500: Internal Server Error"
# Bad request node=pleinde(10): "HTTP Error 500: Internal Server Error"
# Bad request node=pleinde(35): "HTTP Error 500: Internal Server Error"
# Bad request node=pleinde(36): "HTTP Error 500: Internal Server Error"
# Bad request node=plien(7): "HTTP Error 500: Internal Server Error"
# Bad request node=plien(8): "HTTP Error 500: Internal Server Error"
# Bad request node=plien(10): "HTTP Error 500: Internal Server Error"
# Bad request node=plien(35): "HTTP Error 500: Internal Server Error"
# Bad request node=plien(36): "HTTP Error 500: Internal Server Error"
# Bad request node=pleinne(7): "HTTP Error 500: Internal Server Error"
# Bad request node=pleinne(8): "HTTP Error 500: Internal Server Error"
# Bad request node=pleinne(10): "HTTP Error 500: Internal Server Error"
# Bad request node=pleinne(35): "HTTP Error 500: Internal Server Error"
# Bad request node=pleinne(36): "HTTP Error 500: Internal Server Error"
# 	 plein pleines
# 	 plein tas
# 	 plein coeur
# premier
# Bad request node=premeir(7): "HTTP Error 500: Internal Server Error"
# Bad request node=premeir(8): "HTTP Error 500: Internal Server Error"
# Bad request node=premeir(10): "HTTP Error 500: Internal Server Error"
# Bad request node=premeir(35): "HTTP Error 500: Internal Server Error"
# Bad request node=premeir(36): "HTTP Error 500: Internal Server Error"
# 	 premier deuxième
# 	 premier troisième
# 	 premier quatrième
# prêt
# Bad request node=prêtLe(7): "HTTP Error 500: Internal Server Error"
# Bad request node=prêtLe(8): "HTTP Error 500: Internal Server Error"
# Bad request node=prêtLe(10): "HTTP Error 500: Internal Server Error"
# Bad request node=prêtLe(35): "HTTP Error 500: Internal Server Error"
# Bad request node=prêtLe(36): "HTTP Error 500: Internal Server Error"
# 	 prêt prêtLe
# 	 prêt prêtes
# prochain
# 	 prochain dernier
# quoi
# 	 quoi est
# 	 quoi pourquoi
# 	 quoi rien
# seul
# 	 seul petit
# 	 seul grand
# 	 seul aucun
# tout
# 	 tout ceci
# 	 tout simplement
# 	 tout cela
# vert
# 	 vert jaune
# 	 vert noir
# 	 vert rouge
# vivant
# Bad request node=Emmuré(7): "HTTP Error 500: Internal Server Error"
# Bad request node=Emmuré(8): "HTTP Error 500: Internal Server Error"
# Bad request node=Emmuré(10): "HTTP Error 500: Internal Server Error"
# Bad request node=Emmuré(35): "HTTP Error 500: Internal Server Error"
# Bad request node=Emmuré(36): "HTTP Error 500: Internal Server Error"
# 	 vivant vivantes
# 	 vivant non
# 	 vivant résidant
# Noms communs
# Bad request node=NomsS'(7): "HTTP Error 500: Internal Server Error"
# Bad request node=NomsS'(8): "HTTP Error 500: Internal Server Error"
# Bad request node=NomsS'(10): "HTTP Error 500: Internal Server Error"
# Bad request node=NomsS'(35): "HTTP Error 500: Internal Server Error"
# Bad request node=NomsS'(36): "HTTP Error 500: Internal Server Error"
# Bad request node=Pressentiments(7): "HTTP Error 500: Internal Server Error"
# Bad request node=Pressentiments(8): "HTTP Error 500: Internal Server Error"
# Bad request node=Pressentiments(10): "HTTP Error 500: Internal Server Error"
# Bad request node=Pressentiments(35): "HTTP Error 500: Internal Server Error"
# Bad request node=Pressentiments(36): "HTTP Error 500: Internal Server Error"
# Bad request node=Existentiels(7): "HTTP Error 500: Internal Server Error"
# Bad request node=Existentiels(8): "HTTP Error 500: Internal Server Error"
# Bad request node=Existentiels(10): "HTTP Error 500: Internal Server Error"
# Bad request node=Existentiels(35): "HTTP Error 500: Internal Server Error"
# Bad request node=Existentiels(36): "HTTP Error 500: Internal Server Error"
# Bad request node=Vernaculaires(7): "HTTP Error 500: Internal Server Error"
# Bad request node=Vernaculaires(8): "HTTP Error 500: Internal Server Error"
# Bad request node=Vernaculaires(10): "HTTP Error 500: Internal Server Error"
# Bad request node=Vernaculaires(35): "HTTP Error 500: Internal Server Error"
# Bad request node=Vernaculaires(36): "HTTP Error 500: Internal Server Error"
# Bad request node=Chronologiques(7): "HTTP Error 500: Internal Server Error"
# Bad request node=Chronologiques(8): "HTTP Error 500: Internal Server Error"
# Bad request node=Chronologiques(10): "HTTP Error 500: Internal Server Error"
# Bad request node=Chronologiques(35): "HTTP Error 500: Internal Server Error"
# Bad request node=Chronologiques(36): "HTTP Error 500: Internal Server Error"
# Bad request node=Architecturaux(7): "HTTP Error 500: Internal Server Error"
# Bad request node=Architecturaux(8): "HTTP Error 500: Internal Server Error"
# Bad request node=Architecturaux(10): "HTTP Error 500: Internal Server Error"
# Bad request node=Architecturaux(35): "HTTP Error 500: Internal Server Error"
# Bad request node=Architecturaux(36): "HTTP Error 500: Internal Server Error"
# Bad request node=Approximatifs(7): "HTTP Error 500: Internal Server Error"
# Bad request node=Approximatifs(8): "HTTP Error 500: Internal Server Error"
# Bad request node=Approximatifs(10): "HTTP Error 500: Internal Server Error"
# Bad request node=Approximatifs(35): "HTTP Error 500: Internal Server Error"
# Bad request node=Approximatifs(36): "HTTP Error 500: Internal Server Error"
# Bad request node=Représentatifs(7): "HTTP Error 500: Internal Server Error"
# Bad request node=Représentatifs(8): "HTTP Error 500: Internal Server Error"
# Bad request node=Représentatifs(10): "HTTP Error 500: Internal Server Error"
# Bad request node=Représentatifs(35): "HTTP Error 500: Internal Server Error"
# Bad request node=Représentatifs(36): "HTTP Error 500: Internal Server Error"
# 	 Noms communs Architecturaux
# 	 Noms communs Approximatifs
# 	 Noms communs Représentatifs
# aide
# 	 aide aidant
# 	 aide assistance
# 	 aide apporter
# chef
# Bad request node=chefde(7): "HTTP Error 500: Internal Server Error"
# Bad request node=chefde(8): "HTTP Error 500: Internal Server Error"
# Bad request node=chefde(10): "HTTP Error 500: Internal Server Error"
# Bad request node=chefde(35): "HTTP Error 500: Internal Server Error"
# Bad request node=chefde(36): "HTTP Error 500: Internal Server Error"
# 	 chef cheffe
# 	 chef sous
# 	 chef dirigeant
# enfant
# 	 enfant bambin
# 	 enfant adolescent
# 	 enfant nourrisson
# garde
# Bad request node=gardeLa(7): "HTTP Error 500: Internal Server Error"
# Bad request node=gardeLa(8): "HTTP Error 500: Internal Server Error"
# Bad request node=gardeLa(10): "HTTP Error 500: Internal Server Error"
# Bad request node=gardeLa(35): "HTTP Error 500: Internal Server Error"
# Bad request node=gardeLa(36): "HTTP Error 500: Internal Server Error"
# 	 garde gardeLa
# 	 garde gardait
# 	 garde gardant
# gauche
# 	 gauche doite
# 	 gauche droite
# geste
# 	 geste machinal
# 	 geste effort
# 	 geste rituel
# gosse
# Bad request node=beaugosse(7): "HTTP Error 500: Internal Server Error"
# Bad request node=beaugosse(8): "HTTP Error 500: Internal Server Error"
# Bad request node=beaugosse(10): "HTTP Error 500: Internal Server Error"
# Bad request node=beaugosse(35): "HTTP Error 500: Internal Server Error"
# Bad request node=beaugosse(36): "HTTP Error 500: Internal Server Error"
# 	 gosse mec
# 	 gosse blondinet
# 	 gosse gamin
# livre
# 	 livre bouquin
# 	 livre roman
# 	 livre ouvrage
# merci
# Bad request node=MERCI(7): "HTTP Error 500: Internal Server Error"
# Bad request node=MERCI(8): "HTTP Error 500: Internal Server Error"
# Bad request node=MERCI(10): "HTTP Error 500: Internal Server Error"
# Bad request node=MERCI(35): "HTTP Error 500: Internal Server Error"
# Bad request node=MERCI(36): "HTTP Error 500: Internal Server Error"
# Bad request node=merciMerci(7): "HTTP Error 500: Internal Server Error"
# Bad request node=merciMerci(8): "HTTP Error 500: Internal Server Error"
# Bad request node=merciMerci(10): "HTTP Error 500: Internal Server Error"
# Bad request node=merciMerci(35): "HTTP Error 500: Internal Server Error"
# Bad request node=merciMerci(36): "HTTP Error 500: Internal Server Error"
# Bad request node=merciiiii(7): "HTTP Error 500: Internal Server Error"
# Bad request node=merciiiii(8): "HTTP Error 500: Internal Server Error"
# Bad request node=merciiiii(10): "HTTP Error 500: Internal Server Error"
# Bad request node=merciiiii(35): "HTTP Error 500: Internal Server Error"
# Bad request node=merciiiii(36): "HTTP Error 500: Internal Server Error"
# Bad request node=MerciMerci(7): "HTTP Error 500: Internal Server Error"
# Bad request node=MerciMerci(8): "HTTP Error 500: Internal Server Error"
# Bad request node=MerciMerci(10): "HTTP Error 500: Internal Server Error"
# Bad request node=MerciMerci(35): "HTTP Error 500: Internal Server Error"
# Bad request node=MerciMerci(36): "HTTP Error 500: Internal Server Error"
# Bad request node=merciiiiiiii(7): "HTTP Error 500: Internal Server Error"
# Bad request node=merciiiiiiii(8): "HTTP Error 500: Internal Server Error"
# Bad request node=merciiiiiiii(10): "HTTP Error 500: Internal Server Error"
# Bad request node=merciiiiiiii(35): "HTTP Error 500: Internal Server Error"
# Bad request node=merciiiiiiii(36): "HTTP Error 500: Internal Server Error"
# Bad request node=mercimerci(7): "HTTP Error 500: Internal Server Error"
# Bad request node=mercimerci(8): "HTTP Error 500: Internal Server Error"
# Bad request node=mercimerci(10): "HTTP Error 500: Internal Server Error"
# Bad request node=mercimerci(35): "HTTP Error 500: Internal Server Error"
# Bad request node=mercimerci(36): "HTTP Error 500: Internal Server Error"
# 	 merci merciiiiiiii
# 	 merci mercimerci
# 	 merci bravo
# mort
# 	 mort disparition
# 	 mort résurrection
# 	 mort mourant
# ombre
# Bad request node=ombreL'(7): "HTTP Error 500: Internal Server Error"
# Bad request node=ombreL'(8): "HTTP Error 500: Internal Server Error"
# Bad request node=ombreL'(10): "HTTP Error 500: Internal Server Error"
# Bad request node=ombreL'(35): "HTTP Error 500: Internal Server Error"
# Bad request node=ombreL'(36): "HTTP Error 500: Internal Server Error"
# 	 ombre pénombre
# 	 ombre obscurité
# 	 ombre ombrage
# part
# 	 part considération
# 	 part quelque
# 	 part remarque
# poche
# 	 poche mouchoir
# 	 poche douille
# 	 poche sacoche
# professeur
# 	 professeur enseignant
# 	 professeur chercheur
# 	 professeur assistant
# tour
# 	 tour premier
# 	 tour tourde
# 	 tour second
# fois
# 	 fois première
# 	 fois dernière
# 	 fois chaque
# madame
# 	 madame Mademoiselle
# 	 madame mademoiselle
# 	 madame monsieur
# paix
# voix
# Bad request node=voixLa(7): "HTTP Error 500: Internal Server Error"
# Bad request node=voixLa(8): "HTTP Error 500: Internal Server Error"
# Bad request node=voixLa(10): "HTTP Error 500: Internal Server Error"
# Bad request node=voixLa(35): "HTTP Error 500: Internal Server Error"
# Bad request node=voixLa(36): "HTTP Error 500: Internal Server Error"
# 	 voix intonations
# 	 voix voixLa
# affaire
# 	 affaire non
# année
# Bad request node=annéeet(7): "HTTP Error 500: Internal Server Error"
# Bad request node=annéeet(8): "HTTP Error 500: Internal Server Error"
# Bad request node=annéeet(10): "HTTP Error 500: Internal Server Error"
# Bad request node=annéeet(35): "HTTP Error 500: Internal Server Error"
# Bad request node=annéeet(36): "HTTP Error 500: Internal Server Error"
# 	 année annéeet
# 	 année semaine
# arme
# 	 arme fusil
# 	 arme dague
# 	 arme arbalète
# armée
# 	 armée état
# 	 armée infanterie
# 	 armée milice
# attention
# 	 attention particulière
# balle
# Bad request node=minié(7): "HTTP Error 500: Internal Server Error"
# Bad request node=minié(8): "HTTP Error 500: Internal Server Error"
# Bad request node=minié(10): "HTTP Error 500: Internal Server Error"
# Bad request node=minié(35): "HTTP Error 500: Internal Server Error"
# Bad request node=minié(36): "HTTP Error 500: Internal Server Error"
# 	 balle ballon
# 	 balle projectile
# 	 balle chevrotine
# boîte
# 	 boîte boites
# 	 boîte mini
# 	 boîte demi
# bouche
# 	 bouche oreille
# carte
# Bad request node=lacarte(7): "HTTP Error 500: Internal Server Error"
# Bad request node=lacarte(8): "HTTP Error 500: Internal Server Error"
# Bad request node=lacarte(10): "HTTP Error 500: Internal Server Error"
# Bad request node=lacarte(35): "HTTP Error 500: Internal Server Error"
# Bad request node=lacarte(36): "HTTP Error 500: Internal Server Error"
# 	 carte lacarte
# 	 carte cartographie
# cause
# 	 cause faute
# 	 cause conséquence
# 	 cause absence
# chambre
# Bad request node=chmabre(7): "HTTP Error 500: Internal Server Error"
# Bad request node=chmabre(8): "HTTP Error 500: Internal Server Error"
# Bad request node=chmabre(10): "HTTP Error 500: Internal Server Error"
# Bad request node=chmabre(35): "HTTP Error 500: Internal Server Error"
# Bad request node=chmabre(36): "HTTP Error 500: Internal Server Error"
# Bad request node=unechambre(7): "HTTP Error 500: Internal Server Error"
# Bad request node=unechambre(8): "HTTP Error 500: Internal Server Error"
# Bad request node=unechambre(10): "HTTP Error 500: Internal Server Error"
# Bad request node=unechambre(35): "HTTP Error 500: Internal Server Error"
# Bad request node=unechambre(36): "HTTP Error 500: Internal Server Error"
# 	 chambre 3
# 	 chambre salle
# 	 chambre spacieuse
# chance
# Bad request node=chancede(7): "HTTP Error 500: Internal Server Error"
# Bad request node=chancede(8): "HTTP Error 500: Internal Server Error"
# Bad request node=chancede(10): "HTTP Error 500: Internal Server Error"
# Bad request node=chancede(35): "HTTP Error 500: Internal Server Error"
# Bad request node=chancede(36): "HTTP Error 500: Internal Server Error"
# 	 chance chancede
# 	 chance malchance
# chose
# 	 chose quelquechose
# 	 chose quelque
# classe
# Bad request node=laclasse(7): "HTTP Error 500: Internal Server Error"
# Bad request node=laclasse(8): "HTTP Error 500: Internal Server Error"
# Bad request node=laclasse(10): "HTTP Error 500: Internal Server Error"
# Bad request node=laclasse(35): "HTTP Error 500: Internal Server Error"
# Bad request node=laclasse(36): "HTTP Error 500: Internal Server Error"
# 	 classe laclasse
# 	 classe super
# confiance
# Bad request node=conﬁance(7): "HTTP Error 500: Internal Server Error"
# Bad request node=conﬁance(8): "HTTP Error 500: Internal Server Error"
# Bad request node=conﬁance(10): "HTTP Error 500: Internal Server Error"
# Bad request node=conﬁance(35): "HTTP Error 500: Internal Server Error"
# Bad request node=conﬁance(36): "HTTP Error 500: Internal Server Error"
# Bad request node=deconfiance(7): "HTTP Error 500: Internal Server Error"
# Bad request node=deconfiance(8): "HTTP Error 500: Internal Server Error"
# Bad request node=deconfiance(10): "HTTP Error 500: Internal Server Error"
# Bad request node=deconfiance(35): "HTTP Error 500: Internal Server Error"
# Bad request node=deconfiance(36): "HTTP Error 500: Internal Server Error"
# Bad request node=laconfiance(7): "HTTP Error 500: Internal Server Error"
# Bad request node=laconfiance(8): "HTTP Error 500: Internal Server Error"
# Bad request node=laconfiance(10): "HTTP Error 500: Internal Server Error"
# Bad request node=laconfiance(35): "HTTP Error 500: Internal Server Error"
# Bad request node=laconfiance(36): "HTTP Error 500: Internal Server Error"
# 	 confiance conﬁance
# 	 confiance deconfiance
# 	 confiance laconfiance
# couleur
# Bad request node=couelur(7): "HTTP Error 500: Internal Server Error"
# Bad request node=couelur(8): "HTTP Error 500: Internal Server Error"
# Bad request node=couelur(10): "HTTP Error 500: Internal Server Error"
# Bad request node=couelur(35): "HTTP Error 500: Internal Server Error"
# Bad request node=couelur(36): "HTTP Error 500: Internal Server Error"
# Bad request node=couleurde(7): "HTTP Error 500: Internal Server Error"
# Bad request node=couleurde(8): "HTTP Error 500: Internal Server Error"
# Bad request node=couleurde(10): "HTTP Error 500: Internal Server Error"
# Bad request node=couleurde(35): "HTTP Error 500: Internal Server Error"
# Bad request node=couleurde(36): "HTTP Error 500: Internal Server Error"
# Bad request node=decouleur(7): "HTTP Error 500: Internal Server Error"
# Bad request node=decouleur(8): "HTTP Error 500: Internal Server Error"
# Bad request node=decouleur(10): "HTTP Error 500: Internal Server Error"
# Bad request node=decouleur(35): "HTTP Error 500: Internal Server Error"
# Bad request node=decouleur(36): "HTTP Error 500: Internal Server Error"
# Bad request node=lacouleur(7): "HTTP Error 500: Internal Server Error"
# Bad request node=lacouleur(8): "HTTP Error 500: Internal Server Error"
# Bad request node=lacouleur(10): "HTTP Error 500: Internal Server Error"
# Bad request node=lacouleur(35): "HTTP Error 500: Internal Server Error"
# Bad request node=lacouleur(36): "HTTP Error 500: Internal Server Error"
# 	 couleur decouleur
# 	 couleur lacouleur
# 	 couleur teinte
# cour
# Bad request node=laCour(7): "HTTP Error 500: Internal Server Error"
# Bad request node=laCour(8): "HTTP Error 500: Internal Server Error"
# Bad request node=laCour(10): "HTTP Error 500: Internal Server Error"
# Bad request node=laCour(35): "HTTP Error 500: Internal Server Error"
# Bad request node=laCour(36): "HTTP Error 500: Internal Server Error"
# 	 cour courette
# 	 cour récréation
# 	 cour arrière
# cuisine
# 	 cuisine mini
# dame
# 	 dame patronnesse
# 	 dame femme
# 	 dame madame
# dent
# 	 dent machoire
# 	 dent gencive
# 	 dent prémolaire
# droite
# Bad request node=àgauche(7): "HTTP Error 500: Internal Server Error"
# Bad request node=àgauche(8): "HTTP Error 500: Internal Server Error"
# Bad request node=àgauche(10): "HTTP Error 500: Internal Server Error"
# Bad request node=àgauche(35): "HTTP Error 500: Internal Server Error"
# Bad request node=àgauche(36): "HTTP Error 500: Internal Server Error"
# 	 droite àgauche
# 	 droite gauche
# école
# 	 école ex
# 	 école université
# église
# 	 église abbatiale
# 	 église paroissiale
# 	 église chapelle
# envie
# Bad request node=enviede(7): "HTTP Error 500: Internal Server Error"
# Bad request node=enviede(8): "HTTP Error 500: Internal Server Error"
# Bad request node=enviede(10): "HTTP Error 500: Internal Server Error"
# Bad request node=enviede(35): "HTTP Error 500: Internal Server Error"
# Bad request node=enviede(36): "HTTP Error 500: Internal Server Error"
# 	 envie idée
# 	 envie peur
# 	 envie irrépressible
# épaule
# 	 épaule jambe
# 	 épaule poignet
# 	 épaule hanche
# époque
# équipe
# Bad request node=équipede(7): "HTTP Error 500: Internal Server Error"
# Bad request node=équipede(8): "HTTP Error 500: Internal Server Error"
# Bad request node=équipede(10): "HTTP Error 500: Internal Server Error"
# Bad request node=équipede(35): "HTTP Error 500: Internal Server Error"
# Bad request node=équipede(36): "HTTP Error 500: Internal Server Error"
# Bad request node=uneéquipe(7): "HTTP Error 500: Internal Server Error"
# Bad request node=uneéquipe(8): "HTTP Error 500: Internal Server Error"
# Bad request node=uneéquipe(10): "HTTP Error 500: Internal Server Error"
# Bad request node=uneéquipe(35): "HTTP Error 500: Internal Server Error"
# Bad request node=uneéquipe(36): "HTTP Error 500: Internal Server Error"
# 	 équipe équipede
# 	 équipe uneéquipe
# erreur
# espèce
# Bad request node=uneespèce(7): "HTTP Error 500: Internal Server Error"
# Bad request node=uneespèce(8): "HTTP Error 500: Internal Server Error"
# Bad request node=uneespèce(10): "HTTP Error 500: Internal Server Error"
# Bad request node=uneespèce(35): "HTTP Error 500: Internal Server Error"
# Bad request node=uneespèce(36): "HTTP Error 500: Internal Server Error"
# 	 espèce uneespèce
# 	 espèce sous
# face
# 	 face confronté
# 	 face affronter
# 	 face devant
# façon
# 	 façon manière
# 	 façon chose
# 	 façon manières
# faim
# 	 faim soif
# 	 faim famine
# 	 faim affamé
# famille
# 	 famille belle
# 	 famille familiale
# 	 famille mère
# faute
# 	 faute grave
# 	 faute erreur
# 	 faute impardonnable
# femme
# 	 femme fille
# 	 femme jeune
# 	 femme homme
# fenêtre
# Bad request node=lafenêtre(7): "HTTP Error 500: Internal Server Error"
# Bad request node=lafenêtre(8): "HTTP Error 500: Internal Server Error"
# Bad request node=lafenêtre(10): "HTTP Error 500: Internal Server Error"
# Bad request node=lafenêtre(35): "HTTP Error 500: Internal Server Error"
# Bad request node=lafenêtre(36): "HTTP Error 500: Internal Server Error"
# 	 fenêtre lafenêtre
# 	 fenêtre porte
# fête
# 	 fête kermesse
# 	 fête célébration
# 	 fête festivité
# fille
# 	 fille mère
# 	 fille femme
# 	 fille sœur
# fleur
# 	 fleur tulipe
# 	 fleur pétales
# 	 fleur rose
# force
# 	 force volonté
# 	 force puissance
# 	 force persuasion
# forme
# 	 forme une
# 	 forme sorte
# 	 forme contre
# guerre
# Bad request node=laguerre(7): "HTTP Error 500: Internal Server Error"
# Bad request node=laguerre(8): "HTTP Error 500: Internal Server Error"
# Bad request node=laguerre(10): "HTTP Error 500: Internal Server Error"
# Bad request node=laguerre(35): "HTTP Error 500: Internal Server Error"
# Bad request node=laguerre(36): "HTTP Error 500: Internal Server Error"
# 	 guerre laguerre
# 	 guerre pré
# gueule
# Bad request node=gueu(7): "HTTP Error 500: Internal Server Error"
# Bad request node=gueu(8): "HTTP Error 500: Internal Server Error"
# Bad request node=gueu(10): "HTTP Error 500: Internal Server Error"
# Bad request node=gueu(35): "HTTP Error 500: Internal Server Error"
# Bad request node=gueu(36): "HTTP Error 500: Internal Server Error"
# Bad request node=geulle(7): "HTTP Error 500: Internal Server Error"
# Bad request node=geulle(8): "HTTP Error 500: Internal Server Error"
# Bad request node=geulle(10): "HTTP Error 500: Internal Server Error"
# Bad request node=geulle(35): "HTTP Error 500: Internal Server Error"
# Bad request node=geulle(36): "HTTP Error 500: Internal Server Error"
# 	 gueule geulle
# 	 gueule claque
# 	 gueule tronche
# habitude
# 	 habitude accoutumé
# 	 habitude ailleurs
# 	 habitude surtout
# heure
# Bad request node=demiheure(7): "HTTP Error 500: Internal Server Error"
# Bad request node=demiheure(8): "HTTP Error 500: Internal Server Error"
# Bad request node=demiheure(10): "HTTP Error 500: Internal Server Error"
# Bad request node=demiheure(35): "HTTP Error 500: Internal Server Error"
# Bad request node=demiheure(36): "HTTP Error 500: Internal Server Error"
# Bad request node=uneheure(7): "HTTP Error 500: Internal Server Error"
# Bad request node=uneheure(8): "HTTP Error 500: Internal Server Error"
# Bad request node=uneheure(10): "HTTP Error 500: Internal Server Error"
# Bad request node=uneheure(35): "HTTP Error 500: Internal Server Error"
# Bad request node=uneheure(36): "HTTP Error 500: Internal Server Error"
# 	 heure uneheure
# 	 heure demi
# 	 heure demie
# histoire
# Bad request node=hsitoire(7): "HTTP Error 500: Internal Server Error"
# Bad request node=hsitoire(8): "HTTP Error 500: Internal Server Error"
# Bad request node=hsitoire(10): "HTTP Error 500: Internal Server Error"
# Bad request node=hsitoire(35): "HTTP Error 500: Internal Server Error"
# Bad request node=hsitoire(36): "HTTP Error 500: Internal Server Error"
# 	 histoire historie
# 	 histoire hsitoire
# 	 histoire épopée
# idée
# Bad request node=idéede(7): "HTTP Error 500: Internal Server Error"
# Bad request node=idéede(8): "HTTP Error 500: Internal Server Error"
# Bad request node=idéede(10): "HTTP Error 500: Internal Server Error"
# Bad request node=idéede(35): "HTTP Error 500: Internal Server Error"
# Bad request node=idéede(36): "HTTP Error 500: Internal Server Error"
# 	 idée saugrenue
# 	 idée idéede
# image
# 	 image illustration
# impression
# 	 impression sensation
# jambe
# 	 jambe épaule
# 	 jambe hanche
# 	 jambe cheville
# joie
# 	 joie réjouissance
# 	 joie allégresse
# 	 joie gaieté
# journée
# Bad request node=journéede(7): "HTTP Error 500: Internal Server Error"
# Bad request node=journéede(8): "HTTP Error 500: Internal Server Error"
# Bad request node=journéede(10): "HTTP Error 500: Internal Server Error"
# Bad request node=journéede(35): "HTTP Error 500: Internal Server Error"
# Bad request node=journéede(36): "HTTP Error 500: Internal Server Error"
# 	 journée soirée
# 	 journée demi
# 	 journée semaine
# langue
# Bad request node=enlangue(7): "HTTP Error 500: Internal Server Error"
# Bad request node=enlangue(8): "HTTP Error 500: Internal Server Error"
# Bad request node=enlangue(10): "HTTP Error 500: Internal Server Error"
# Bad request node=enlangue(35): "HTTP Error 500: Internal Server Error"
# Bad request node=enlangue(36): "HTTP Error 500: Internal Server Error"
# Bad request node=langueLa(7): "HTTP Error 500: Internal Server Error"
# Bad request node=langueLa(8): "HTTP Error 500: Internal Server Error"
# Bad request node=langueLa(10): "HTTP Error 500: Internal Server Error"
# Bad request node=langueLa(35): "HTTP Error 500: Internal Server Error"
# Bad request node=langueLa(36): "HTTP Error 500: Internal Server Error"
# 	 langue langueLa
# 	 langue français
# 	 langue grammaire
# lettre
# Bad request node=lalettre(7): "HTTP Error 500: Internal Server Error"
# Bad request node=lalettre(8): "HTTP Error 500: Internal Server Error"
# Bad request node=lalettre(10): "HTTP Error 500: Internal Server Error"
# Bad request node=lalettre(35): "HTTP Error 500: Internal Server Error"
# Bad request node=lalettre(36): "HTTP Error 500: Internal Server Error"
# 	 lettre lalettre
# 	 lettre adressée
# 	 lettre missive
# lèvre
# Bad request node=levres(7): "HTTP Error 500: Internal Server Error"
# Bad request node=levres(8): "HTTP Error 500: Internal Server Error"
# Bad request node=levres(10): "HTTP Error 500: Internal Server Error"
# Bad request node=levres(35): "HTTP Error 500: Internal Server Error"
# Bad request node=levres(36): "HTTP Error 500: Internal Server Error"
# Bad request node=pomette(7): "HTTP Error 500: Internal Server Error"
# Bad request node=pomette(8): "HTTP Error 500: Internal Server Error"
# Bad request node=pomette(10): "HTTP Error 500: Internal Server Error"
# Bad request node=pomette(35): "HTTP Error 500: Internal Server Error"
# Bad request node=pomette(36): "HTTP Error 500: Internal Server Error"
# 	 lèvre paupière
# 	 lèvre commissure
# 	 lèvre sourcil
# ligne
# Bad request node=lignede(7): "HTTP Error 500: Internal Server Error"
# Bad request node=lignede(8): "HTTP Error 500: Internal Server Error"
# Bad request node=lignede(10): "HTTP Error 500: Internal Server Error"
# Bad request node=lignede(35): "HTTP Error 500: Internal Server Error"
# Bad request node=lignede(36): "HTTP Error 500: Internal Server Error"
# Bad request node=ligneCette(7): "HTTP Error 500: Internal Server Error"
# Bad request node=ligneCette(8): "HTTP Error 500: Internal Server Error"
# Bad request node=ligneCette(10): "HTTP Error 500: Internal Server Error"
# Bad request node=ligneCette(35): "HTTP Error 500: Internal Server Error"
# Bad request node=ligneCette(36): "HTTP Error 500: Internal Server Error"
# 	 ligne ligneCette
# 	 ligne plateforme
# 	 ligne mire
# lumière
# Bad request node=lumièreet(7): "HTTP Error 500: Internal Server Error"
# Bad request node=lumièreet(8): "HTTP Error 500: Internal Server Error"
# Bad request node=lumièreet(10): "HTTP Error 500: Internal Server Error"
# Bad request node=lumièreet(35): "HTTP Error 500: Internal Server Error"
# Bad request node=lumièreet(36): "HTTP Error 500: Internal Server Error"
# 	 lumière lumièreet
# 	 lumière luminosité
# 	 lumière lueur
# main
# 	 main mainet
# maison
# Bad request node=maisonde(7): "HTTP Error 500: Internal Server Error"
# Bad request node=maisonde(8): "HTTP Error 500: Internal Server Error"
# Bad request node=maisonde(10): "HTTP Error 500: Internal Server Error"
# Bad request node=maisonde(35): "HTTP Error 500: Internal Server Error"
# Bad request node=maisonde(36): "HTTP Error 500: Internal Server Error"
# 	 maison bâtisse
# 	 maison villa
# 	 maison grange
# maman
# 	 maman grand
# 	 maman mère
# 	 maman papa
# manière
# Bad request node=demanière(7): "HTTP Error 500: Internal Server Error"
# Bad request node=demanière(8): "HTTP Error 500: Internal Server Error"
# Bad request node=demanière(10): "HTTP Error 500: Internal Server Error"
# Bad request node=demanière(35): "HTTP Error 500: Internal Server Error"
# Bad request node=demanière(36): "HTTP Error 500: Internal Server Error"
# Bad request node=manièrede(7): "HTTP Error 500: Internal Server Error"
# Bad request node=manièrede(8): "HTTP Error 500: Internal Server Error"
# Bad request node=manièrede(10): "HTTP Error 500: Internal Server Error"
# Bad request node=manièrede(35): "HTTP Error 500: Internal Server Error"
# Bad request node=manièrede(36): "HTTP Error 500: Internal Server Error"
# 	 manière façons
# 	 manière chose
# 	 manière façon
# marche
# 	 marche marcherait
# 	 marche marchait
# 	 marche fonctionne
# merde
# 	 merde sous
# 	 merde chiasse
# 	 merde putain
# mère
# 	 mère maman
# 	 mère cousine
# 	 mère sœur
# minute
# Bad request node=10minute(7): "HTTP Error 500: Internal Server Error"
# Bad request node=10minute(8): "HTTP Error 500: Internal Server Error"
# Bad request node=10minute(10): "HTTP Error 500: Internal Server Error"
# Bad request node=10minute(35): "HTTP Error 500: Internal Server Error"
# Bad request node=10minute(36): "HTTP Error 500: Internal Server Error"
# 	 minute 10minute
# 	 minute demi
# 	 minute secondes
# musique
# Bad request node=demusique(7): "HTTP Error 500: Internal Server Error"
# Bad request node=demusique(8): "HTTP Error 500: Internal Server Error"
# Bad request node=demusique(10): "HTTP Error 500: Internal Server Error"
# Bad request node=demusique(35): "HTTP Error 500: Internal Server Error"
# Bad request node=demusique(36): "HTTP Error 500: Internal Server Error"
# Bad request node=musqiue(7): "HTTP Error 500: Internal Server Error"
# Bad request node=musqiue(8): "HTTP Error 500: Internal Server Error"
# Bad request node=musqiue(10): "HTTP Error 500: Internal Server Error"
# Bad request node=musqiue(35): "HTTP Error 500: Internal Server Error"
# Bad request node=musqiue(36): "HTTP Error 500: Internal Server Error"
# Bad request node=lamusique(7): "HTTP Error 500: Internal Server Error"
# Bad request node=lamusique(8): "HTTP Error 500: Internal Server Error"
# Bad request node=lamusique(10): "HTTP Error 500: Internal Server Error"
# Bad request node=lamusique(35): "HTTP Error 500: Internal Server Error"
# Bad request node=lamusique(36): "HTTP Error 500: Internal Server Error"
# 	 musique musicale
# 	 musique musiquette
# 	 musique chanson
# nuit
# odeur
# 	 odeur parfum
# 	 odeur puanteur
# 	 odeur effluve
# oreille
# 	 oreille oreil
# 	 oreille oreillette
# parole
# Bad request node=laparole(7): "HTTP Error 500: Internal Server Error"
# Bad request node=laparole(8): "HTTP Error 500: Internal Server Error"
# Bad request node=laparole(10): "HTTP Error 500: Internal Server Error"
# Bad request node=laparole(35): "HTTP Error 500: Internal Server Error"
# Bad request node=laparole(36): "HTTP Error 500: Internal Server Error"
# 	 parole laparole
# 	 parole voix
# partie
# 	 partie totalité
# 	 partie majeure
# 	 partie moitié
# peau
# 	 peau épiderme
# peine
# Bad request node=lapeine(7): "HTTP Error 500: Internal Server Error"
# Bad request node=lapeine(8): "HTTP Error 500: Internal Server Error"
# Bad request node=lapeine(10): "HTTP Error 500: Internal Server Error"
# Bad request node=lapeine(35): "HTTP Error 500: Internal Server Error"
# Bad request node=lapeine(36): "HTTP Error 500: Internal Server Error"
# Bad request node=peinede(7): "HTTP Error 500: Internal Server Error"
# Bad request node=peinede(8): "HTTP Error 500: Internal Server Error"
# Bad request node=peinede(10): "HTTP Error 500: Internal Server Error"
# Bad request node=peinede(35): "HTTP Error 500: Internal Server Error"
# Bad request node=peinede(36): "HTTP Error 500: Internal Server Error"
# 	 peine lapeine
# 	 peine peinede
# 	 peine seulement
# pensée
# 	 pensée idéologie
# 	 pensée non
# 	 pensée philosophie
# personne
# 	 personne quelqu'
# 	 personne quelqu
# 	 personne seule
# peur
# 	 peur honte
# 	 peur craint
# 	 peur craindre
# photo
# 	 photo photographie
# pièce
# Bad request node=unepièce(7): "HTTP Error 500: Internal Server Error"
# Bad request node=unepièce(8): "HTTP Error 500: Internal Server Error"
# Bad request node=unepièce(10): "HTTP Error 500: Internal Server Error"
# Bad request node=unepièce(35): "HTTP Error 500: Internal Server Error"
# Bad request node=unepièce(36): "HTTP Error 500: Internal Server Error"
# 	 pièce unepièce
# 	 pièce piècette
# pierre
# Bad request node=pière(7): "HTTP Error 500: Internal Server Error"
# Bad request node=pière(8): "HTTP Error 500: Internal Server Error"
# Bad request node=pière(10): "HTTP Error 500: Internal Server Error"
# Bad request node=pière(35): "HTTP Error 500: Internal Server Error"
# Bad request node=pière(36): "HTTP Error 500: Internal Server Error"
# 	 pierre roche
# 	 pierre brique
# 	 pierre granit
# place
# Bad request node=palce(7): "HTTP Error 500: Internal Server Error"
# Bad request node=palce(8): "HTTP Error 500: Internal Server Error"
# Bad request node=palce(10): "HTTP Error 500: Internal Server Error"
# Bad request node=palce(35): "HTTP Error 500: Internal Server Error"
# Bad request node=palce(36): "HTTP Error 500: Internal Server Error"
# Bad request node=placede(7): "HTTP Error 500: Internal Server Error"
# Bad request node=placede(8): "HTTP Error 500: Internal Server Error"
# Bad request node=placede(10): "HTTP Error 500: Internal Server Error"
# Bad request node=placede(35): "HTTP Error 500: Internal Server Error"
# Bad request node=placede(36): "HTTP Error 500: Internal Server Error"
# 	 place disposition
# 	 place position
# 	 place mise
# police
# Bad request node=lapolice(7): "HTTP Error 500: Internal Server Error"
# Bad request node=lapolice(8): "HTTP Error 500: Internal Server Error"
# Bad request node=lapolice(10): "HTTP Error 500: Internal Server Error"
# Bad request node=lapolice(35): "HTTP Error 500: Internal Server Error"
# Bad request node=lapolice(36): "HTTP Error 500: Internal Server Error"
# Bad request node=depolice(7): "HTTP Error 500: Internal Server Error"
# Bad request node=depolice(8): "HTTP Error 500: Internal Server Error"
# Bad request node=depolice(10): "HTTP Error 500: Internal Server Error"
# Bad request node=depolice(35): "HTTP Error 500: Internal Server Error"
# Bad request node=depolice(36): "HTTP Error 500: Internal Server Error"
# 	 police policière
# 	 police gendarmerie
# 	 police policier
# porte
# 	 porte entrouvre
# 	 porte portait
# 	 porte portera
# présence
# Bad request node=laprésence(7): "HTTP Error 500: Internal Server Error"
# Bad request node=laprésence(8): "HTTP Error 500: Internal Server Error"
# Bad request node=laprésence(10): "HTTP Error 500: Internal Server Error"
# Bad request node=laprésence(35): "HTTP Error 500: Internal Server Error"
# Bad request node=laprésence(36): "HTTP Error 500: Internal Server Error"
# Bad request node=présencede(7): "HTTP Error 500: Internal Server Error"
# Bad request node=présencede(8): "HTTP Error 500: Internal Server Error"
# Bad request node=présencede(10): "HTTP Error 500: Internal Server Error"
# Bad request node=présencede(35): "HTTP Error 500: Internal Server Error"
# Bad request node=présencede(36): "HTTP Error 500: Internal Server Error"
# 	 présence non
# 	 présence absence
# 	 présence omniprésence
# prison
# 	 prison incarcéré
# 	 prison emprisonnement
# 	 prison geôle
# putain
# 	 putain mec
# 	 putain foutu
# 	 putain merde
# question
# Bad request node=laquestion(7): "HTTP Error 500: Internal Server Error"
# Bad request node=laquestion(8): "HTTP Error 500: Internal Server Error"
# Bad request node=laquestion(10): "HTTP Error 500: Internal Server Error"
# Bad request node=laquestion(35): "HTTP Error 500: Internal Server Error"
# Bad request node=laquestion(36): "HTTP Error 500: Internal Server Error"
# 	 question réponse
# 	 question interrogation
# 	 question problématique
# raison
# Bad request node=raisonde(7): "HTTP Error 500: Internal Server Error"
# Bad request node=raisonde(8): "HTTP Error 500: Internal Server Error"
# Bad request node=raisonde(10): "HTTP Error 500: Internal Server Error"
# Bad request node=raisonde(35): "HTTP Error 500: Internal Server Error"
# Bad request node=raisonde(36): "HTTP Error 500: Internal Server Error"
# 	 raison conséquence
# 	 raison tort
# 	 raison cause
# réponse
# 	 réponse question
# 	 réponse réaction
# robe
# 	 robe mini
# 	 robe tunique
# 	 robe bustier
# route
# Bad request node=routeLa(7): "HTTP Error 500: Internal Server Error"
# Bad request node=routeLa(8): "HTTP Error 500: Internal Server Error"
# Bad request node=routeLa(10): "HTTP Error 500: Internal Server Error"
# Bad request node=routeLa(35): "HTTP Error 500: Internal Server Error"
# Bad request node=routeLa(36): "HTTP Error 500: Internal Server Error"
# 	 route routeLa
# 	 route autoroute
# salle
# Bad request node=sallede(7): "HTTP Error 500: Internal Server Error"
# Bad request node=sallede(8): "HTTP Error 500: Internal Server Error"
# Bad request node=sallede(10): "HTTP Error 500: Internal Server Error"
# Bad request node=sallede(35): "HTTP Error 500: Internal Server Error"
# Bad request node=sallede(36): "HTTP Error 500: Internal Server Error"
# Bad request node=salleLa(7): "HTTP Error 500: Internal Server Error"
# ...
# Bad request node=jettant(8): "HTTP Error 500: Internal Server Error"
# Bad request node=jettant(10): "HTTP Error 500: Internal Server Error"
# Bad request node=jettant(35): "HTTP Error 500: Internal Server Error"
# Bad request node=jettant(36): "HTTP Error 500: Internal Server Error"
# Bad request node=jeterais(7): "HTTP Error 500: Internal Server Error"
# Bad request node=jeterais(8): "HTTP Error 500: Internal Server Error"
# Bad request node=jeterais(10): "HTTP Error 500: Internal Server Error"
# Bad request node=jeterais(35): "HTTP Error 500: Internal Server Error"
# Bad request node=jeterais(36): "HTTP Error 500: Internal Server Error"
# 	 jeter jettant
# 	 jeter jeterais
# 	 jeter jeté
# jouer
# 	 jouer rejouer
# 	 jouer amuser
# 	 jouer joué
# jurer
# 	 jurer promettre
# 	 jurer parjurer
# 	 jurer trahir
# lâcher
# 	 lâcher abandonner
# 	 lâcher prendre
# 	 lâcher lâché
# laisser
# 	 laisser laissant
# 	 laisser rester
# 	 laisser laissé
# lancer
# 	 lancer relancer
# 	 lancer entamer
# 	 lancer lancé
# lever
# 	 lever lève
# 	 lever levé
# 	 lever levée
# lire
# 	 lire re
# 	 lire voir
# 	 lire relire
# maintenir
# 	 maintenir conserver
# 	 maintenir stabiliser
# 	 maintenir consolider
# manger
# 	 manger cuisiner
# 	 manger mangé
# 	 manger boire
# manquer
# Bad request node=râter(7): "HTTP Error 500: Internal Server Error"
# Bad request node=râter(8): "HTTP Error 500: Internal Server Error"
# Bad request node=râter(10): "HTTP Error 500: Internal Server Error"
# Bad request node=râter(35): "HTTP Error 500: Internal Server Error"
# Bad request node=râter(36): "HTTP Error 500: Internal Server Error"
# 	 manquer louper
# 	 manquer manqué
# 	 manquer rater
# marcher
# 	 marcher marchant
# 	 marcher balader
# 	 marcher traîner
# marier
# 	 marier convoler
# 	 marier fiancer
# 	 marier démarier
# mener
# 	 mener entamer
# 	 mener mené
# 	 mener continuer
# mentir
# 	 mentir contredire
# 	 mentir tromper
# 	 mentir tricher
# mettre
# Bad request node=mettrent(7): "HTTP Error 500: Internal Server Error"
# Bad request node=mettrent(8): "HTTP Error 500: Internal Server Error"
# Bad request node=mettrent(10): "HTTP Error 500: Internal Server Error"
# Bad request node=mettrent(35): "HTTP Error 500: Internal Server Error"
# Bad request node=mettrent(36): "HTTP Error 500: Internal Server Error"
# 	 mettre mis
# 	 mettre remettre
# 	 mettre placer
# monter
# 	 monter descendre
# 	 monter démonter
# 	 monter gravir
# montrer
# 	 montrer présenter
# 	 montrer remontrer
# 	 montrer reconnaître
# mourir
# 	 mourir tuer
# 	 mourir périr
# 	 mourir crever
# naître
# 	 naître éclore
# 	 naître renaître
# 	 naître grandir
# obliger
# 	 obliger autoriser
# 	 obliger obligé
# 	 obliger amener
# occuper
# 	 occuper préoccuper
# 	 occuper occupé
# 	 occuper organiser
# offrir
# 	 offrir donner
# 	 offrir fournir
# 	 offrir apporter
# oser
# 	 oser osant
# 	 oser essayer
# 	 oser osé
# oublier
# 	 oublier exagérer
# 	 oublier rappeler
# 	 oublier occulter
# ouvrir
# 	 ouvrir entrouvrir
# 	 ouvrir refermer
# 	 ouvrir fermer
# paraître
# 	 paraître paraissant
# 	 paraître paru
# 	 paraître sembler
# parler
# Bad request node=parlerde(7): "HTTP Error 500: Internal Server Error"
# Bad request node=parlerde(8): "HTTP Error 500: Internal Server Error"
# Bad request node=parlerde(10): "HTTP Error 500: Internal Server Error"
# Bad request node=parlerde(35): "HTTP Error 500: Internal Server Error"
# Bad request node=parlerde(36): "HTTP Error 500: Internal Server Error"
# 	 parler entendre
# 	 parler penser
# 	 parler parlé
# partir
# Bad request node=partirde(7): "HTTP Error 500: Internal Server Error"
# Bad request node=partirde(8): "HTTP Error 500: Internal Server Error"
# Bad request node=partirde(10): "HTTP Error 500: Internal Server Error"
# Bad request node=partirde(35): "HTTP Error 500: Internal Server Error"
# Bad request node=partirde(36): "HTTP Error 500: Internal Server Error"
# 	 partir dès
# 	 partir repartir
# 	 partir avant
# passer
# 	 passer laisser
# 	 passer rentrer
# 	 passer traverser
# payer
# 	 payer débourser
# 	 payer facturer
# 	 payer payé
# penser
# 	 penser considérer
# 	 penser admettre
# 	 penser parler
# perdre
# Bad request node=perdrent(7): "HTTP Error 500: Internal Server Error"
# Bad request node=perdrent(8): "HTTP Error 500: Internal Server Error"
# Bad request node=perdrent(10): "HTTP Error 500: Internal Server Error"
# Bad request node=perdrent(35): "HTTP Error 500: Internal Server Error"
# Bad request node=perdrent(36): "HTTP Error 500: Internal Server Error"
# 	 perdre abandonner
# 	 perdre perdu
# 	 perdre gagner
# permettre
# Bad request node=permetter(7): "HTTP Error 500: Internal Server Error"
# Bad request node=permetter(8): "HTTP Error 500: Internal Server Error"
# Bad request node=permetter(10): "HTTP Error 500: Internal Server Error"
# Bad request node=permetter(35): "HTTP Error 500: Internal Server Error"
# Bad request node=permetter(36): "HTTP Error 500: Internal Server Error"
# 	 permettre permetter
# 	 permettre permet
# 	 permettre amener
# plaire
# 	 plaire ravir
# 	 plaire surprendre
# 	 plaire charmer
# pleurer
# 	 pleurer chialer
# 	 pleurer pleurnicher
# 	 pleurer soupirer
# porter
# 	 porter porterait
# 	 porter revêtir
# 	 porter porté
# poser
# 	 poser questionner
# 	 poser pauser
# 	 poser réfléchir
# pousser
# 	 pousser repousser
# 	 pousser poussé
# 	 pousser amener
# pouvoir
# Bad request node=depouvoir(7): "HTTP Error 500: Internal Server Error"
# Bad request node=depouvoir(8): "HTTP Error 500: Internal Server Error"
# Bad request node=depouvoir(10): "HTTP Error 500: Internal Server Error"
# Bad request node=depouvoir(35): "HTTP Error 500: Internal Server Error"
# Bad request node=depouvoir(36): "HTTP Error 500: Internal Server Error"
# 	 pouvoir depouvoir
# 	 pouvoir permettre
# préférer
# 	 préférer préférant
# 	 préférer penser
# 	 préférer considérer
# prendre
# 	 prendre reprendre
# 	 prendre pris
# 	 prendre prenant
# préparer
# 	 préparer organiser
# 	 préparer accompagner
# 	 préparer réaliser
# présenter
# 	 présenter montrer
# 	 présenter introduire
# 	 présenter réaliser
# prévenir
# 	 prévenir protéger
# 	 prévenir avertir
# 	 prévenir alerter
# prier
# 	 prier agenouiller
# 	 prier priant
# 	 prier bénir
# promettre
# 	 promettre espérer
# 	 promettre promet
# 	 promettre jurer
# proposer
# Bad request node=deproposer(7): "HTTP Error 500: Internal Server Error"
# Bad request node=deproposer(8): "HTTP Error 500: Internal Server Error"
# Bad request node=deproposer(10): "HTTP Error 500: Internal Server Error"
# Bad request node=deproposer(35): "HTTP Error 500: Internal Server Error"
# Bad request node=deproposer(36): "HTTP Error 500: Internal Server Error"
# 	 proposer fournir
# 	 proposer apporter
# 	 proposer offrir
# protéger
# 	 protéger protège
# 	 protéger sécuriser
# 	 protéger prémunir
# quitter
# 	 quitter rejoindre
# 	 quitter regagner
# 	 quitter retourner
# raconter
# 	 raconter relater
# 	 raconter conter
# 	 raconter parler
# ramener
# 	 ramener retrouver
# 	 ramener rentrer
# 	 ramener regagner
# rappeler
# Bad request node=rapeller(7): "HTTP Error 500: Internal Server Error"
# Bad request node=rapeller(8): "HTTP Error 500: Internal Server Error"
# Bad request node=rapeller(10): "HTTP Error 500: Internal Server Error"
# Bad request node=rapeller(35): "HTTP Error 500: Internal Server Error"
# Bad request node=rapeller(36): "HTTP Error 500: Internal Server Error"
# 	 rappeler préciser
# 	 rappeler mentionner
# 	 rappeler souligner
# recevoir
# Bad request node=derecevoir(7): "HTTP Error 500: Internal Server Error"
# Bad request node=derecevoir(8): "HTTP Error 500: Internal Server Error"
# Bad request node=derecevoir(10): "HTTP Error 500: Internal Server Error"
# Bad request node=derecevoir(35): "HTTP Error 500: Internal Server Error"
# Bad request node=derecevoir(36): "HTTP Error 500: Internal Server Error"
# 	 recevoir donner
# 	 recevoir réceptionner
# 	 recevoir envoyer
# reconnaître
# 	 reconnaître discerner
# 	 reconnaître admettre
# 	 reconnaître considérer
# réfléchir
# 	 réfléchir cogiter
# 	 réfléchir questionner
# 	 réfléchir repenser
# refuser
# 	 refuser accepter
# 	 refuser renoncer
# 	 refuser autoriser
# regarder
# 	 regarder regardé
# 	 regarder voir
# 	 regarder regardant
# rejoindre
# 	 rejoindre rejoint
# 	 rejoindre rentrer
# 	 rejoindre rallier
# remarquer
# 	 remarquer penser
# 	 remarquer rappeler
# 	 remarquer souligner
# remettre
# 	 remettre remettant
# 	 remettre reprendre
# 	 remettre remis
# remonter
# 	 remonter descendre
# 	 remonter remonté
# 	 remonter démonter
# rencontrer
# 	 rencontrer côtoyer
# 	 rencontrer croiser
# 	 rencontrer inviter
# rendre
# Bad request node=rendrent(7): "HTTP Error 500: Internal Server Error"
# Bad request node=rendrent(8): "HTTP Error 500: Internal Server Error"
# Bad request node=rendrent(10): "HTTP Error 500: Internal Server Error"
# Bad request node=rendrent(35): "HTTP Error 500: Internal Server Error"
# Bad request node=rendrent(36): "HTTP Error 500: Internal Server Error"
# 	 rendre rendent
# 	 rendre rend
# 	 rendre rendant
# rentrer
# 	 rentrer rentré
# 	 rentrer retourner
# 	 rentrer ramener
# répéter
# Bad request node=repeter(7): "HTTP Error 500: Internal Server Error"
# Bad request node=repeter(8): "HTTP Error 500: Internal Server Error"
# Bad request node=repeter(10): "HTTP Error 500: Internal Server Error"
# Bad request node=repeter(35): "HTTP Error 500: Internal Server Error"
# Bad request node=repeter(36): "HTTP Error 500: Internal Server Error"
# 	 répéter réitérer
# 	 répéter rabâcher
# 	 répéter répété
# répondre
# Bad request node=derépondre(7): "HTTP Error 500: Internal Server Error"
# Bad request node=derépondre(8): "HTTP Error 500: Internal Server Error"
# Bad request node=derépondre(10): "HTTP Error 500: Internal Server Error"
# Bad request node=derépondre(35): "HTTP Error 500: Internal Server Error"
# Bad request node=derépondre(36): "HTTP Error 500: Internal Server Error"
# Bad request node=répondrent(7): "HTTP Error 500: Internal Server Error"
# Bad request node=répondrent(8): "HTTP Error 500: Internal Server Error"
# Bad request node=répondrent(10): "HTTP Error 500: Internal Server Error"
# Bad request node=répondrent(35): "HTTP Error 500: Internal Server Error"
# Bad request node=répondrent(36): "HTTP Error 500: Internal Server Error"
# 	 répondre répondrent
# 	 répondre répond
# 	 répondre répondant
# reposer
# 	 reposer pauser
# 	 reposer reposé
# 	 reposer détendre
# reprendre
# 	 reprendre remettre
# 	 reprendre prendre
# 	 reprendre retrouver
# ressembler
# 	 ressembler correspondre
# 	 ressembler penser
# 	 ressembler ressemblant
# rester
# 	 rester laisser
# 	 rester tenir
# 	 rester restant
# retenir
# 	 retenir manquer
# 	 retenir rappeler
# 	 retenir résumer
# retirer
# 	 retirer ôter
# 	 retirer détacher
# 	 retirer supprimer
# retourner
# 	 retourner revenir
# 	 retourner renvoyer
# 	 retourner rentrer
# retrouver
# 	 retrouver trouver
# 	 retrouver reprendre
# 	 retrouver ramener
# réussir
# 	 réussir échouer
# 	 réussir préparer
# 	 réussir réaliser
# réveiller
# 	 réveiller rendormir
# 	 réveiller réveillé
# 	 réveiller réveil
# revenir
# Bad request node=retrourner(7): "HTTP Error 500: Internal Server Error"
# Bad request node=retrourner(8): "HTTP Error 500: Internal Server Error"
# Bad request node=retrourner(10): "HTTP Error 500: Internal Server Error"
# Bad request node=retrourner(35): "HTTP Error 500: Internal Server Error"
# Bad request node=retrourner(36): "HTTP Error 500: Internal Server Error"
# 	 revenir reprendre
# 	 revenir retourner
# 	 revenir ramener
# rêver
# 	 rêver cauchemarder
# 	 rêver fantasmer
# 	 rêver penser
# revoir
# Bad request node=rerevoir(7): "HTTP Error 500: Internal Server Error"
# Bad request node=rerevoir(8): "HTTP Error 500: Internal Server Error"
# Bad request node=rerevoir(10): "HTTP Error 500: Internal Server Error"
# Bad request node=rerevoir(35): "HTTP Error 500: Internal Server Error"
# Bad request node=rerevoir(36): "HTTP Error 500: Internal Server Error"
# 	 revoir repenser
# 	 revoir reparler
# 	 revoir voir
# rire
# 	 rire pleurer
# 	 rire pouffer
# 	 rire rigoler
# risquer
# 	 risquer risqueriez
# 	 risquer risquant
# 	 risquer éviter
# rouler
# 	 rouler arsouiller
# 	 rouler pédaler
# 	 rouler roulé
# sauter
# 	 sauter sauté
# 	 sauter bondir
# 	 sauter foncer
# sauver
# 	 sauver détruire
# 	 sauver sauvé
# 	 sauver tuer
# savoir
# 	 savoir connaitre
# 	 savoir comprendre
# 	 savoir dire
# sembler
# Bad request node=parraître(7): "HTTP Error 500: Internal Server Error"
# Bad request node=parraître(8): "HTTP Error 500: Internal Server Error"
# Bad request node=parraître(10): "HTTP Error 500: Internal Server Error"
# Bad request node=parraître(35): "HTTP Error 500: Internal Server Error"
# Bad request node=parraître(36): "HTTP Error 500: Internal Server Error"
# 	 sembler avérer
# 	 sembler paraître
# 	 sembler être
# sentir
# 	 sentir sentant
# 	 sentir sente
# 	 sentir ressentir
# séparer
# 	 séparer dissocier
# 	 séparer isoler
# 	 séparer détacher
# serrer
# Bad request node=desserer(7): "HTTP Error 500: Internal Server Error"
# Bad request node=desserer(8): "HTTP Error 500: Internal Server Error"
# Bad request node=desserer(10): "HTTP Error 500: Internal Server Error"
# Bad request node=desserer(35): "HTTP Error 500: Internal Server Error"
# Bad request node=desserer(36): "HTTP Error 500: Internal Server Error"
# 	 serrer serrant
# 	 serrer desserrer
# 	 serrer resserrer
# servir
# 	 servir permettre
# 	 servir resservir
# 	 servir servant
# sortir
# Bad request node=resortir(7): "HTTP Error 500: Internal Server Error"
# Bad request node=resortir(8): "HTTP Error 500: Internal Server Error"
# Bad request node=resortir(10): "HTTP Error 500: Internal Server Error"
# Bad request node=resortir(35): "HTTP Error 500: Internal Server Error"
# Bad request node=resortir(36): "HTTP Error 500: Internal Server Error"
# 	 sortir rentrer
# 	 sortir extirper
# 	 sortir enfermer
# souffrir
# 	 souffrir souffert
# 	 souffrir pâtir
# 	 souffrir craindre
# sourire
# 	 sourire demi
# 	 sourire souriant
# souvenir
# Bad request node=souvenirde(7): "HTTP Error 500: Internal Server Error"
# Bad request node=souvenirde(8): "HTTP Error 500: Internal Server Error"
# Bad request node=souvenirde(10): "HTTP Error 500: Internal Server Error"
# Bad request node=souvenirde(35): "HTTP Error 500: Internal Server Error"
# Bad request node=souvenirde(36): "HTTP Error 500: Internal Server Error"
# 	 souvenir souvenant
# 	 souvenir remémorer
# 	 souvenir ressouvenir
# suffire
# 	 suffire suffi
# 	 suffire suffirait
# 	 suffire suffisant
# suivre
# 	 suivre suivez
# 	 suivre poursuivre
# 	 suivre continuer
# taire
# 	 taire ignorer
# 	 taire murmurer
# 	 taire parler
# tendre
# 	 tendre tend
# 	 tendre doux
# 	 tendre douce
# tenir
# 	 tenir maintenir
# 	 tenir prendre
# 	 tenir tenant
# tenter
# 	 tenter retenter
# 	 tenter tentant
# 	 tenter convaincre
# terminer
# 	 terminer entamer
# 	 terminer achever
# 	 terminer clôturer
# tirer
# 	 tirer tirerais
# 	 tirer tiré
# 	 tirer tirant
# tomber
# 	 tomber tombé
# 	 tomber tombant
# 	 tomber chuter
# toucher
# 	 toucher frotter
# 	 toucher approcher
# 	 toucher caresser
# tourner
# 	 tourner revenir
# 	 tourner tourné
# 	 tourner retourner
# traîner
# 	 traîner marcher
# 	 traîner traînasser
# 	 traîner traînant
# traiter
# 	 traiter gérer
# 	 traiter aborder
# 	 traiter diagnostiquer
# travailler
# 	 travailler collaborer
# 	 travailler retravailler
# 	 travailler travaillant
# traverser
# 	 traverser enjamber
# 	 traverser franchir
# 	 traverser traversée
# tromper
# 	 tromper berner
# 	 tromper surprendre
# 	 tromper piéger
# trouver
# 	 trouver dégoter
# 	 trouver retrouver
# 	 trouver dénicher
# tuer
# 	 tuer exterminer
# 	 tuer venger
# 	 tuer décapiter
# utiliser
# 	 utiliser réutiliser
# 	 utiliser activer
# 	 utiliser appliquer
# valoir
# 	 valoir prétendre
# 	 valoir remarquer
# 	 valoir réclamer
# vendre
# Bad request node=vendrent(7): "HTTP Error 500: Internal Server Error"
# Bad request node=vendrent(8): "HTTP Error 500: Internal Server Error"
# Bad request node=vendrent(10): "HTTP Error 500: Internal Server Error"
# Bad request node=vendrent(35): "HTTP Error 500: Internal Server Error"
# Bad request node=vendrent(36): "HTTP Error 500: Internal Server Error"
# 	 vendre commercialiser
# 	 vendre brader
# 	 vendre racheter
# venir
# 	 venir revenir
# 	 venir voir
# 	 venir amener
# vivre
# Bad request node=devivre(7): "HTTP Error 500: Internal Server Error"
# Bad request node=devivre(8): "HTTP Error 500: Internal Server Error"
# Bad request node=devivre(10): "HTTP Error 500: Internal Server Error"
# Bad request node=devivre(35): "HTTP Error 500: Internal Server Error"
# Bad request node=devivre(36): "HTTP Error 500: Internal Server Error"
# 	 vivre mourir
# 	 vivre travailler
# 	 vivre survivre
# voir
# 	 voir observer
# 	 voir lire
# 	 voir dire
# voler
# 	 voler envoler
# 	 voler volé
# 	 voler dérober
# vouloir
# 	 vouloir préférer
# 	 vouloir renoncer
# 	 vouloir prétendre
